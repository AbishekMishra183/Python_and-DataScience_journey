# %% [markdown]
# # data Scaling

# %%
KNN 
- distance based 
Features(columns):scale chai same huno parxa column haru ko
# Out:
#   Cell In[1], line 2
#     - distance based
#                ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

# %%
data =pd.read_csv('Diabetes.csv')
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
x=data[['Glucose','Age']]
y=data.Outcome

# %%
x
# Out:
#      Glucose  Age
# 0        148   50
# 1         85   31
# 2        183   32
# 3         89   21
# 4        137   33
# ..       ...  ...
# 763      101   63
# 764      122   27
# 765      121   30
# 766      126   47
# 767       93   23
#
# [768 rows x 2 columns]

# %%
x.describe()
# Out:
#           Glucose         Age
# count  768.000000  768.000000
# mean   120.894531   33.240885
# std     31.972618   11.760232
# min      0.000000   21.000000
# 25%     99.000000   24.000000
# 50%    117.000000   29.000000
# 75%    140.250000   41.000000
# max    199.000000   81.000000

# %% [markdown]
# range chai farak farak xa yo 2 ota ko yesto vayepacchi 1 ota ley arko ko feature lai dominant garxa
# so that keeping the information constant we have to scale it
#
# => yesma imgage liyauna ko lagi first ma cell lai markdown garne ani
# google bata copy image garne ani tespachhi paste garne yeta tera doublle path copy hunxa 1 ota lai remove garne

# %% [markdown]
# MinMax Scaler
# ![image.png](attachment:a8d45b2a-cfcb-4291-a98c-08e0f66416a8.png)

# %% [markdown]
# Standard Sclaer => mean 0 and sd=1
# ![image.png](attachment:0dae8f73-82bc-4039-8a4e-bc136456d8e5.png)

# %% [markdown]
# # Robust Scaling
# => median and interquartile range is used in this scaling
# => extreme values haru xa vanye yo use garinxa
# ![image.png](attachment:13cb09fa-9926-4a0c-8b0f-0555e0194074.png)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# steps:
# 1.split data
# 2. train_data(fit_transform)
# 3.test_data(transform)

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.8,random_state=22)

# %%
xtrain.head()
# Out:
#      Glucose  Age
# 695      142   43
# 141      106   38
# 281      129   39
# 6         78   26
# 509      120   64

# %%
scaler=StandardScaler()
xtrain_s=scaler.fit_transform(xtrain)
xtest_s=scaler.transform(xtest)

# %%
xtrain_s
# Out:
# array([[ 0.71841144,  0.74639535],
#        [-0.44064252,  0.33970557],
#        [ 0.29986418,  0.42104353],
#        [-1.34212892, -0.63634988],
#        [ 0.01010069,  2.45449239],
#        [-0.0542912 ,  0.99040921],
#        [ 0.10668852, -0.96170169],
#        [-1.14895327, -0.47367397],
#        [-0.66601412, -0.0669842 ],
#        [ 0.9115871 ,  1.31576103],
#        [ 1.07256681, -0.88036374],
#        [ 0.04229663, -0.31099806],
#        [-0.18307497, -0.71768783],
#        [ 0.04229663, -0.71768783],
#        [ 0.13888446,  1.47843693],
#        [ 1.52331002, -0.0669842 ],
#        [-0.82699383,  1.80378875],
#        [-0.31185874, -0.31099806],
#        [ 2.03844511,  0.17702967],
#        [-0.47283846,  0.99040921],
#        [ 1.26574247,  0.50238148],
#        [-0.18307497,  0.01435376],
#        [-0.92358166, -0.96170169],
#        [-0.40844657, -0.79902579],
#        [-0.47283846,  2.29181648],
#        [-1.30993298, -0.96170169],
#        [-0.2796628 , -0.88036374],
# ...

# %%
xtrains=pd.DataFrame(xtrain_s,columns=xtrain.columns) # to see the output in the dataframe format
xtrains.head()
# Out:
#     Glucose       Age
# 0  0.718411  0.746395
# 1 -0.440643  0.339706
# 2  0.299864  0.421044
# 3 -1.342129 -0.636350
# 4  0.010101  2.454492

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier(n_neighbors=7)
knn.fit(xtrain_s,ytrain)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
yprediction=knn.predict(xtest_s)

# %% [markdown]
# # Decision Trees

# %%
-tree Structure

# %%
 jasko child xaina teslai leaf node vaninxa

distance based vaye pacchi chai scaling garno parxa natrw pardaiana 

Linearly Seperable  ma matrw logistic ley kam garxa natrw tesko perforamnce better xaina 
testo case ma chai decision tree will be the better option

leaf node ma chai class ko label hunxa (yes /no)

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split

from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
data=sns.load_dataset('iris')

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
x=data.drop('species',axis=1)
y=data.species

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=12)

# %%
dmodel=DecisionTreeClassifier()
dmodel.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
dmodel.predict([[4,3.1,1,0.5]])
# Out:
# C:\Users\Acer\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['setosa'], dtype=object)

# %%
ypredection=dmodel.predict(xtest)

# %%
ypredection
# Out:
# array(['setosa', 'virginica', 'setosa', 'versicolor', 'virginica',
#        'virginica', 'virginica', 'setosa', 'virginica', 'setosa',
#        'versicolor', 'setosa', 'setosa', 'setosa', 'versicolor',
#        'virginica', 'virginica', 'versicolor', 'setosa', 'virginica',
#        'setosa', 'versicolor', 'virginica', 'versicolor', 'setosa',
#        'virginica', 'virginica', 'versicolor', 'setosa', 'setosa'],
#       dtype=object)

# %%
accuracy=accuracy_score(ytest,ypredection)
print(f'Accuracy:{accuracy:.2%}')
# Out:
# Accuracy:93.33%

# %%
from sklearn.tree import plot_tree   # to make the decision tree 
import matplotlib.pyplot as plt

# %%
clas =list(y.unique())
clas
#clas=data['species'].unique
# Out:
# ['setosa', 'versicolor', 'virginica']

# %%
feature=list(x.columns)
feature
# Out:
# ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']

# %%
plot_tree(dmodel,feature_names=feature,class_names=clas,filled=True)    # demodel is the name of the variable 
plt.show()

# %% [markdown]
# left side true right side false

# %%
disadvantages of the descision tree
- Overfitting
