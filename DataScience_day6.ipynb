# %%
import pandas as pd

# %% [markdown]
# EDA=> visulaization

# %%
Tableau - Dashboard:No coding 

Machine Learning

# %%
df=pd.read_csv("Salary_Data.csv")

# %%
print(df)
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %%
df.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
# skewness- positively skewed( when the data is splitted in near the positive side start tira vanayrew bujhne 
# Negatively skewed-(when the data is splitted near the negative side or  last tira vanyrw bujhne
# if it have the eqaul distribution then it is no skewed data

# %% [markdown]
# Median
# Q1-Q3 vanda mathi ko line lai whisker vaninxa
# Q1:
# Q3:
# IQR:(Q3-Q1)
# lower bound:Q1-1.5*IQR
# upper bound:Q3+1.5*IQR
# outlier: significantly different then other(rest of the data vanda xuttai hunxa)(do more investigation to know the exact data)
# whisker vanda bhairw data aaye teslai outlier vaninxa

# %%
Outlier : Do more investigration
 To test the outlier point we can use  the technique :
1. Remove
2. Replace with the uppper bound or replace with the lower bound

# %% [markdown]
# # Machine Learning
# for example: 2 ko value     6
# input     output
# 2         6     2**3-2
# 3    ko  24     3**3-3
# 4   ko   60     4**3-4
# 5        ?      5**3-5
#
# Model vanako formula jastai ho jasle input lai output ma mapping garxa
#
# x=5    y=x**3-1
#  aba yo input rw output heryarw yauta pattern find out garxa rw output generate garxa

# %%
df.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
# yo data lai salary predict garna lai garna sakinxa 
using the attribute like 
Input: Age,Gender,.........
Output: Salary

# %%
import pandas as pd

# %%
data=pd.read_csv("insurance.csv")
data.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
df=pd.read_csv("diabetes.csv")

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# TO predict diabetes

# %%
Machine Learning : 
1. Supervised Learning  
2.Unsupervised Learning 
3. Reinforcement Learning

# %%
1. Supervised Learning 
Input - Output (diyako hunxa teo output ko pattern haryarw sikxa )
(Labeled data)
it is of two types
1. regression
=> (x,y)(y vanako chai output, target value )=> numerical value xa vanye (28327332 is  the numeric value )

2. classification
=>y(): class label( let 0, 1 hunxa and tesma  ma classification in  the different class)

# %% [markdown]
# # Machine learning ko supervised learning ko regression vitrw
# 1. Linear Regression:

# %%
data.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
#Age-> Charges (age bata charges predection garne )
df=data[['age','expenses']]
df.head()
# Out:
#    age  expenses
# 0   19  16884.92
# 1   18   1725.55
# 2   28   4449.46
# 3   33  21984.47
# 4   32   3866.86

# %%
x(age)          y(expenses)    xy             x**2
19              16884          19*16884





a=
b=

# %%
formula:
b=(nsum(xy)-sum(x)sum(y))/nsum(x**2)-sum(x)**2
when sum is the summataion 
sum(x)=>summation of x
sum(y)=>summation of y
sum(x**2)
sum(x)**2

value of a

a=mean(y)-b*mean(x)

y=a+bx
