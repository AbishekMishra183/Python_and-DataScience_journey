# %% [markdown]
# <a href="https://colab.research.google.com/github/AbishekMishra183/data-science-ml-journey/blob/main/DataScience_day28.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📘 Day 28: Revision Notes – NumPy & Pandas
# ---
#
# ## 🧠 NumPy vs Pandas – Comparison Summary
#
#
#
#
# | Feature         | NumPy                      | Pandas                          |
# |-----------------|----------------------------|----------------------------------|
# | Structure       | Homogeneous Arrays         | Heterogeneous Tables (DataFrame) |
# | Data Labels     | No                         | Yes (Index, Column names)        |
# | Speed           | Very Fast (C-level speed)  | Slower, more flexible            |
# | Ideal For       | Numerical computation      | Data manipulation & analysis     |
# | Indexing        | Integer-based              | Label & integer-based            |
# | Tools           | Reshape, Slice, Broadcast  | Read/write, GroupBy, Fillna, EDA |
#
#
# from IPython.nbformat import v4 as nbf
# import os
#
#
# ## 🔢 NumPy – Numerical Python
#
# ### ✅ Key Concepts:
# - **np.array()**: Creates arrays (1D, 2D, nD)
# - Fast operations with arrays using **vectorization**
# - **Broadcasting**: Perform operations across mismatched shapes
# - Common methods:
#   - `np.mean()`, `np.sum()`, `np.max()`, `np.min()`
#   - `np.reshape()`, `np.arange()`, `np.linspace()`
# """))
#
# # Code cell for NumPy example
# cells.append(nbf.new_code_cell("""
#
# import numpy as np
#
# arr = np.array([1, 2, 3, 4])
#
# print("Mean:", np.mean(arr))
#
# print("Squared:", arr ** 2)
# """))
#
# #  Pandas concepts
#
#
# ## 📊 Pandas – Python Data Analysis Library
#
# ### ✅ Key Concepts:
#
# #### 🔹 Series:
# - 1D labeled array (like a column)
# - `pd.Series(data)`
#
# #### 🔹 DataFrame:
# - 2D table (rows & columns)
# - Created from dict, list of lists, NumPy arrays, etc.
# - `pd.DataFrame(data)`
#
# #### 📥 Reading Files:
# - `pd.read_csv("filename.csv")`
#
# #### 📈 Common Methods:
# - `.head()`, `.tail()`, `.info()`, `.describe()`
# - `.loc[]`: label-based access
# - `.iloc[]`: position-based access
# - `.groupby()`, `.sort_values()`, `.fillna()`, `.dropna()`
# """))
#
# # Pandas example
#
# import pandas as pd
#
# data = pd.DataFrame({
#
#     'Name': ['Alice', 'Bob'],
#
#     'Score': [85, 92]
# })
#
# print(data.head())       #### Access first 10 elements by column (default)
#
#
# print(data['Name'])
#       # Column access
# print(data.iloc[0])
#       # Row by index
#
#
# # Markdown cell for image
#
# ## 📊 Visual: NumPy vs Pandas
#
#
#
# **NumPy** is ideal for numerical array operations.
# **Pandas** adds labeling and is perfect for real-world, tabular data.
#
#
# ## 🔁 Summary Table:
#
# | Feature         | NumPy                   | Pandas                          |
# |-----------------|-------------------------|----------------------------------|
# | Structure       | Homogeneous Arrays      | Heterogeneous Tables (DataFrame) |
# | Data Labels     | No                      | Yes (Index, Column names)        |
# | Speed           | Faster for math ops     | Slower but flexible              |
# | Use Case        | Scientific computing    | Data analysis, tabular data      |
#
#
#
# ---
#
# ## 🌱 Final Thought:
# Understanding the foundation makes everything else easier.
# NumPy gives us speed, Pandas gives us structure. Both together = data science power combo. 💪
#
#
#
#
#
# #To understand all the concepts in the depth i have follow
#
# https://www.geeksforgeeks.org/numpy-cheat-sheet/
