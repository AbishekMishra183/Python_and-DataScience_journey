# %% [markdown]
# # Linear Regression

# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("insurance.csv")

# %%
data.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
# age -> charges 
df=data[['age','expenses']]
df.head()
# Out:
#    age  expenses
# 0   19  16884.92
# 1   18   1725.55
# 2   28   4449.46
# 3   33  21984.47
# 4   32   3866.86

# %% [markdown]
# age: input variable
# expenses: output variable

# %% [markdown]
# y=a+bx
# is like
# y=mx+c:
# equation of the st line
# regression ley line fit gardinxa

# %%
plt.scatter(df.age,df.expenses)
plt.xlabel('age')
plt.ylabel('expenses')
plt.show()

# %%
## Salary Data

# %%
data=pd.read_csv("Salary_Data.csv")

# %%
data.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
plt.scatter(data.Age,data.Salary)
plt.xlabel("Age")
plt.title("Age vs Salary")
plt.ylabel("Salary")
plt.show()

# %%
minidata=data.sample(1000)

# %%
minidata.head()
# Out:
#        Age  Gender    Education Level                Job Title  \
# 6404  25.0  Female        High School          Sales Executive
# 2023  30.0  Female    Master's Degree      Front end Developer
# 1983  43.0  Female                PhD  Senior Project Engineer
# 1631  27.0    Male  Bachelor's Degree      Front end Developer
# 6444  29.0  Female  Bachelor's Degree        Financial Manager
#
#       Years of Experience    Salary
# 6404                  1.0   35000.0
# 2023                  5.0  105000.0
# 1983                 14.0  190000.0
# 1631                  3.0   80000.0
# 6444                  4.0   55000.0

# %%
plt.scatter(minidata.Age,minidata.Salary)
plt.show()

# %%
# to use the  machine learning algorithm we use the library name sciktlearn which has buitin algorithm we can use directly

# %%
# !pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
Steps:
1.import libraries
2.Read data
3.check linear relationship exist or not 
4.x,y
5.model fitting

# %%
from sklearn.linear_model import LinearRegression

# %%
sklearn vanyako yauta folder jasto ho teo vitrw linear model vanee file xa rw teo vitrw ni class xa teo vanayako chai liner regression ho

# %%
linear.model.py
     class linear regression
# Out:
#   Cell In[30], line 2
#     class linear regression
#     ^
# IndentationError: unexpected indent

# %%
x: input Variable(independent variable)                 // x vanyako data frame noii huno parxa always 
y:output Variable                                       // Series noii huno parxa

# %%
x = minidata[['Age']]
y = minidata['Salary']                                      # single square bracket rw dot yautai ho
data.isnull().sum()                                         # to check if the nulll value exist or not 
data.dropna(inplace=True)
minidata.isnull().sum()                                    # to check if the nulll value exist or not 
minidata.dropna(inplace=True)                              # to drop the exact value where there exist null

# %%
linearmodel =LinearRegression()                          # linear regression vanne class ko obj banayako that is linearmodel
linearmodel.fit(x,y)                                     # model fit garne ko lagi . fit vanne function ho use garinxxa
# Out:
# LinearRegression()

# %%
a=linearmodel.intercept_       # to find the value of the a that is how much value is computed 
print('Intercept:',a)
# Out:
# Intercept: -57920.44607809326

# %%
b=linearmodel.coef_
print(b)
# Out:
# [5173.12253068]

# %% [markdown]
# Charges=-57920.44607809+5173.1223*age

# %%
# age=40
#.predict vanne fxn use garyerw predict pani garna sakinxa \

linearmodel.predict([[40]])
                      # 40 lai pani dataframe noii banayrw dino parxa kina vanye training ma j xa tei dino parx a
# Out:
# C:\Users\Acer\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([149004.4551491])

# %%
linearmodel.predict([[30]])
# Out:
# C:\Users\Acer\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([97273.2298423])

# %% [markdown]
# data
# x
# y
# model fit
# .predict()
#
# Error
# Evaluation
# 1.Evaluation Metrics
# MSE
# RMSE
# MAE

# %%
x                y(actual        y(predicated)               error(actual-predicted)
30                   25000        300000                      5000
40                   60000        500000                        10000

# %% [markdown]
# model fit vayaepacchi predection ko lagi predection ko  value dinxa  test
# garno aghi teslai evalute garne
# tespacchi matrw teslai use garxau

# %% [markdown]
# # Regression Evaluation Metrices
# 1.MSE(Mean Sqaure Error)
# -aayo ko sabbai error ko square garinxa aba chai tesko mean nikalinxa
# -first square of mean
# -second  ma chai tesko mean nikalinxa
#
# 2.RMSE(Root Mean Square Error)
# -> RMSE ley cahi MSE ma cahi root lagidinxa
# -> Square root of MSE
# -> yesle chai big range lai small ma liyauna ko lagihelp garxa
#
# 3. MAE(Mean Absolute Error)
# ->Error ko absolute value nikalinxa
# -> error lai tei scale ma positive matrw banaunxa

# %%
x.head()
# Out:
#        Age
# 6404  25.0
# 2023  30.0
# 1983  43.0
# 1631  27.0
# 6444  29.0

# %%
ypred=linearmodel.predict(x)
ypred
# Out:
# array([ 71407.6171889 ,  97273.2298423 , 164523.82274114,  81753.86225026,
#         92100.10731162, 149004.4551491 , 164523.82274114, 138658.21008774,
#        154177.57767978,  76580.73971958, 112792.59743434, 159350.70021046,
#        190389.43539453,  92100.10731162, 138658.21008774, 174870.0678025 ,
#        128311.96502638, 138658.21008774, 159350.70021046,  66234.49465822,
#         76580.73971958, 102446.35237298,  81753.86225026, 117965.71996502,
#        174870.0678025 , 112792.59743434, 117965.71996502,  86926.98478094,
#         97273.2298423 , 195562.55792521, 102446.35237298,  97273.2298423 ,
#        107619.47490366,  81753.86225026, 200735.68045589, 123138.8424957 ,
#         92100.10731162,  86926.98478094, 154177.57767978, 174870.0678025 ,
#        128311.96502638, 117965.71996502, 169696.94527182,  76580.73971958,
#        128311.96502638,  76580.73971958, 128311.96502638, 128311.96502638,
# ...

# %%
y
# Out:
# 6404     35000.0
# 2023    105000.0
# 1983    190000.0
# 1631     80000.0
# 6444     55000.0
#           ...
# 1104    110000.0
# 206      50000.0
# 4107    160000.0
# 3516    150000.0
# 1996    195000.0
# Name: Salary, Length: 1000, dtype: float64

# %%
error=y-ypred
error
# Out:
# 6404   -36407.617189
# 2023     7726.770158
# 1983    25476.177259
# 1631    -1753.862250
# 6444   -37100.107312
#             ...
# 1104    33419.260280
# 206    -52446.352373
# 4107    -4523.822741
# 3516   -14523.822741
# 1996     -562.557925
# Name: Salary, Length: 1000, dtype: float64

# %%
# Assignment 
-> find

# %%
y=a+bx
Charges=a+b*age

a= intercept
b= coefficient
